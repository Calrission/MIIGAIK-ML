# %%
# !pip install pandas
# !pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import os
base = os.path.abspath("")
data3 = pd.read_excel(f'{base}/sem01/data_3_course.xlsx')
data4 = pd.read_excel(f'{base}/sem01/data_4_course.xlsx')

# %%
data3
# Out:
#                   Timestamp                                ID Рейтинг  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503   704,0
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb   646,0
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624,0
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68   579,0
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5   632,0
# ..                      ...                               ...     ...
# 218 2020-05-20 11:49:38.801  bd416140ecdb32b6dbd7f40820bf63b1   517,0
# 219 2020-05-20 11:57:07.326  e6f5eb76b34e7ab7bac753e6cb0a2279   634,0
# 220 2020-05-21 16:33:15.899  1341f488fae5f1ccf164960fd6506cd0   584,0
# 221 2020-05-24 01:21:31.946  04bcb5c9d23813ffa940e1febb27fadc   646,0
# 222 2020-05-19 04:24:29.000  9d19b0d5f4fc8d7edc2258406f872c4e   694,0
#
#      Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# ...

# %%
data3.head(4)
# Out:
#                 Timestamp                                ID Рейтинг  \
# 0 2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503   704,0
# 1 2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb   646,0
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624,0
# 3 2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68   579,0
#
#    Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 0                     181  NaN                            Язык SQL
# 1                     181  NaN   Высокопроизводительные вычисления
# 2                     185  NaN    Безопасность компьютерных систем
# 3                     182  NaN         Statistical Learning Theory
#
#   Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 0   Высокопроизводительные вычисления                Матричные вычисления
# 1    Безопасность компьютерных систем                            Язык SQL
# ...

# %%
data3.tail(4)
# Out:
#                   Timestamp                                ID Рейтинг  \
# 219 2020-05-20 11:57:07.326  e6f5eb76b34e7ab7bac753e6cb0a2279   634,0
# 220 2020-05-21 16:33:15.899  1341f488fae5f1ccf164960fd6506cd0   584,0
# 221 2020-05-24 01:21:31.946  04bcb5c9d23813ffa940e1febb27fadc   646,0
# 222 2020-05-19 04:24:29.000  9d19b0d5f4fc8d7edc2258406f872c4e   694,0
#
#      Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 219                     184  NaN                   Теория баз данных
# 220                     188  NaN                            Язык SQL
# 221                     186  NaN                   Теория баз данных
# 222                     188  NaN    Безопасность компьютерных систем
#
#     Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 219    Безопасность компьютерных систем       Моделирование временных рядов
# 220                   Теория баз данных    Безопасность компьютерных систем
# ...

# %%
data3.sample()
# Out:
#                   Timestamp                                ID Рейтинг  \
# 168 2020-05-18 22:20:36.242  c7544f6c00a5164efdef675410d62e94   585,0
#
#      Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 168                     183  NaN                            Язык SQL
#
#     Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 168                   Теория баз данных    Безопасность компьютерных систем
#
#             Весенний курс по выбору, приоритет 1  \
# 168  Промышленное программирование на языке Java
#
#     Весенний курс по выбору, приоритет 2 Весенний курс по выбору, приоритет 3  \
# 168               Дискретная оптимизация                    Компьютерные сети
#
#     Вы заполняете анкету в первый раз?
# 168                                 Да

# %%
data3.dtypes
# Out:
# Timestamp                               datetime64[ns]
# ID                                              object
# Рейтинг                                         object
# Группа (в формате 182)                           int64
# МИ?                                            float64
# Осенний курс по выбору, приоритет 1             object
# Осенний курс по выбору, приоритет 2             object
# Осенний курс по выбору, приоритет 3             object
# Весенний курс по выбору, приоритет 1            object
# Весенний курс по выбору, приоритет 2            object
# Весенний курс по выбору, приоритет 3            object
# Вы заполняете анкету в первый раз?              object
# dtype: object

# %%
data3.columns
# Out:
# Index(['Timestamp', 'ID', 'Рейтинг', 'Группа (в формате 182)', 'МИ?',
#        'Осенний курс по выбору, приоритет 1',
#        'Осенний курс по выбору, приоритет 2',
#        'Осенний курс по выбору, приоритет 3',
#        'Весенний курс по выбору, приоритет 1',
#        'Весенний курс по выбору, приоритет 2',
#        'Весенний курс по выбору, приоритет 3',
#        'Вы заполняете анкету в первый раз?'],
#       dtype='object')

# %%
data3.loc[2]
# Out:
# Timestamp                                     2020-05-15 03:12:41.480000
# ID                                      30f3653fc176d54e89ac3179c455c6dd
# Рейтинг                                                            624,0
# Группа (в формате 182)                                               185
# МИ?                                                                  NaN
# Осенний курс по выбору, приоритет 1     Безопасность компьютерных систем
# Осенний курс по выбору, приоритет 2                 Матричные вычисления
# Осенний курс по выбору, приоритет 3        Моделирование временных рядов
# Весенний курс по выбору, приоритет 1              Дискретная оптимизация
# Весенний курс по выбору, приоритет 2                 Машинное обучение 2
# Весенний курс по выбору, приоритет 3                    Численные методы
# Вы заполняете анкету в первый раз?                                    Да
# Name: 2, dtype: object

# %%
type(data3.loc[2])
# Out:
# pandas.core.series.Series

# %%
data3.loc[2:4]
# Out:
#                 Timestamp                                ID Рейтинг  \
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624,0
# 3 2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68   579,0
# 4 2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5   632,0
#
#    Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 2                     185  NaN    Безопасность компьютерных систем
# 3                     182  NaN         Statistical Learning Theory
# 4                     183  NaN   Высокопроизводительные вычисления
#
#   Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 2                Матричные вычисления       Моделирование временных рядов
# 3   Высокопроизводительные вычисления                Матричные вычисления
# 4    Безопасность компьютерных систем                   Теория баз данных
#
#   Весенний курс по выбору, приоритет 1 Весенний курс по выбору, приоритет 2  \
# ...

# %%
data3.iloc[2:4]
# Out:
#                 Timestamp                                ID Рейтинг  \
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd   624,0
# 3 2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68   579,0
#
#    Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 2                     185  NaN    Безопасность компьютерных систем
# 3                     182  NaN         Statistical Learning Theory
#
#   Осенний курс по выбору, приоритет 2 Осенний курс по выбору, приоритет 3  \
# 2                Матричные вычисления       Моделирование временных рядов
# 3   Высокопроизводительные вычисления                Матричные вычисления
#
#   Весенний курс по выбору, приоритет 1 Весенний курс по выбору, приоритет 2  \
# 2               Дискретная оптимизация                  Машинное обучение 2
# 3               Дискретная оптимизация                     Численные методы
#
#   Весенний курс по выбору, приоритет 3 Вы заполняете анкету в первый раз?
# ...

# %%
data3.iloc[2:4, 2:6]
# Out:
#   Рейтинг  Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1
# 2   624,0                     185  NaN    Безопасность компьютерных систем
# 3   579,0                     182  NaN         Statistical Learning Theory

# %%
data3.loc[2:4, 'Рейтинг':'Осенний курс по выбору, приоритет 1']
# Out:
#   Рейтинг  Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1
# 2   624,0                     185  NaN    Безопасность компьютерных систем
# 3   579,0                     182  NaN         Statistical Learning Theory
# 4   632,0                     183  NaN   Высокопроизводительные вычисления

# %%
data3[['Рейтинг', 'Осенний курс по выбору, приоритет 1']].head(3)
# Out:
#   Рейтинг Осенний курс по выбору, приоритет 1
# 0   704,0                            Язык SQL
# 1   646,0   Высокопроизводительные вычисления
# 2   624,0    Безопасность компьютерных систем

# %%
data3[data3['Группа (в формате 182)'] == 182].sample(3)
# Out:
#                  Timestamp                                ID Рейтинг  \
# 18 2020-05-15 19:44:33.132  af20596134e83f3ca61259b325aa9688   518,0
# 89 2020-05-18 18:01:52.604  fd784637a19d65bbe5b07d6efac5a05d   624,0
# 35 2020-05-16 21:11:40.100  2662600c2c37e11e62f6ee0b88452f22   627,0
#
#     Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 18                     182  NaN         Statistical Learning Theory
# 89                     182  NaN    Безопасность компьютерных систем
# 35                     182  1.0         Statistical Learning Theory
#
#                 Осенний курс по выбору, приоритет 2  \
# 18  Сбор и обработка данных с помощью краудсорсинга
# 89                      Statistical Learning Theory
# 35  Сбор и обработка данных с помощью краудсорсинга
#
#                   Осенний курс по выбору, приоритет 3  \
# 18                  Высокопроизводительные вычисления
# 89                               Матричные вычисления
# ...

# %%
data3['Рейтинг'] = data3['Рейтинг'].apply(lambda x: float(x.replace(',', '.')))

strange_feature = data3['Рейтинг'] ** 2 + data3['Группа (в формате 182)']
strange_feature.head()
# Out:
# 0    495797.0
# 1    417497.0
# 2    389561.0
# 3    335423.0
# 4    399607.0
# dtype: float64

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Timestamp                             223 non-null    datetime64[ns]
#  1   ID                                    223 non-null    object
#  2   Рейтинг                               223 non-null    float64
#  3   Группа (в формате 182)                223 non-null    int64
#  4   МИ?                                   18 non-null     float64
#  5   Осенний курс по выбору, приоритет 1   223 non-null    object
#  6   Осенний курс по выбору, приоритет 2   223 non-null    object
#  7   Осенний курс по выбору, приоритет 3   223 non-null    object
#  8   Весенний курс по выбору, приоритет 1  223 non-null    object
#  9   Весенний курс по выбору, приоритет 2  223 non-null    object
# ...

# %%
data3[data3["Рейтинг"] > 700].head(4)
# Out:
#                  Timestamp                                ID  Рейтинг  \
# 0  2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503    704.0
# 6  2020-05-15 11:42:16.910  e4caca755ee0bdd711e18fb8084958b5    723.0
# 9  2020-05-15 13:29:10.789  d6c079f1ff869c8c84fa3ed30bd67e0e    733.0
# 12 2020-05-15 16:13:05.416  77c7b37ee521df16ccff23ba50c893d4    734.0
#
#     Группа (в формате 182)  МИ? Осенний курс по выбору, приоритет 1  \
# 0                      181  NaN                            Язык SQL
# 6                      181  NaN         Statistical Learning Theory
# 9                      181  NaN                   Теория баз данных
# 12                     183  NaN   Высокопроизводительные вычисления
#
#    Осенний курс по выбору, приоритет 2  \
# 0    Высокопроизводительные вычисления
# 6     Безопасность компьютерных систем
# 9    Высокопроизводительные вычисления
# 12                            Язык SQL
#
#                 Осенний курс по выбору, приоритет 3  \
# ...

# %%
data3['Рейтинг'].rank() / data4.shape[0]
# Out:
# 0      0.820628
# 1      0.495516
# 2      0.320628
# 3      0.123318
# 4      0.401345
#          ...
# 218    0.013453
# 219    0.410314
# 220    0.136771
# 221    0.495516
# 222    0.778027
# Name: Рейтинг, Length: 223, dtype: float64

# %%
data3["Рейтинг"].describe()
# Out:
# count    223.000000
# mean     648.816143
# std       58.255552
# min      495.000000
# 25%      609.000000
# 50%      647.000000
# 75%      691.000000
# max      784.000000
# Name: Рейтинг, dtype: float64

# %%
data3.Timestamp
# Out:
# 0     2020-05-15 01:12:50.543
# 1     2020-05-15 02:46:48.066
# 2     2020-05-15 03:12:41.480
# 3     2020-05-15 04:43:08.994
# 4     2020-05-15 07:47:17.197
#                 ...
# 218   2020-05-20 11:49:38.801
# 219   2020-05-20 11:57:07.326
# 220   2020-05-21 16:33:15.899
# 221   2020-05-24 01:21:31.946
# 222   2020-05-19 04:24:29.000
# Name: Timestamp, Length: 223, dtype: datetime64[ns]

# %%
data3.Рейтинг
# Out:
# 0      704.0
# 1      646.0
# 2      624.0
# 3      579.0
# 4      632.0
#        ...
# 218    517.0
# 219    634.0
# 220    584.0
# 221    646.0
# 222    694.0
# Name: Рейтинг, Length: 223, dtype: float64

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Timestamp                             223 non-null    datetime64[ns]
#  1   ID                                    223 non-null    object
#  2   Рейтинг                               223 non-null    float64
#  3   Группа (в формате 182)                223 non-null    int64
#  4   МИ?                                   18 non-null     float64
#  5   Осенний курс по выбору, приоритет 1   223 non-null    object
#  6   Осенний курс по выбору, приоритет 2   223 non-null    object
#  7   Осенний курс по выбору, приоритет 3   223 non-null    object
#  8   Весенний курс по выбору, приоритет 1  223 non-null    object
#  9   Весенний курс по выбору, приоритет 2  223 non-null    object
# ...

# %%
naData = data3.isna()

# %%
naData.sum()
# Out:
# Timestamp                                 0
# ID                                        0
# Рейтинг                                   0
# Группа (в формате 182)                    0
# МИ?                                     205
# Осенний курс по выбору, приоритет 1       0
# Осенний курс по выбору, приоритет 2       0
# Осенний курс по выбору, приоритет 3       0
# Весенний курс по выбору, приоритет 1      0
# Весенний курс по выбору, приоритет 2      0
# Весенний курс по выбору, приоритет 3      0
# Вы заполняете анкету в первый раз?        1
# dtype: int64

# %%
data3.groupby("Осенний курс по выбору, приоритет 1").count()[['ID']]
# Out:
#                                                     ID
# Осенний курс по выбору, приоритет 1
# Statistical Learning Theory                         14
# Безопасность компьютерных систем                    81
# Высокопроизводительные вычисления                   18
# Матричные вычисления                                14
# Моделирование временных рядов                       23
# Принятие решений в условиях риска и неопределён...   3
# Сбор и обработка данных с помощью краудсорсинга     26
# Теория баз данных                                   13
# Язык SQL                                            31

# %%
data3.groupby("Осенний курс по выбору, приоритет 1")["Рейтинг"].mean()
# Out:
# Осенний курс по выбору, приоритет 1
# Statistical Learning Theory                             646.857143
# Безопасность компьютерных систем                        661.827160
# Высокопроизводительные вычисления                       647.055556
# Матричные вычисления                                    671.857143
# Моделирование временных рядов                           648.217391
# Принятие решений в условиях риска и неопределённости    582.666667
# Сбор и обработка данных с помощью краудсорсинга         662.769231
# Теория баз данных                                       629.384615
# Язык SQL                                                609.612903
# Name: Рейтинг, dtype: float64

# %%
corrmat = data3[["Рейтинг", "Группа (в формате 182)"]].corr()

# %%
# !pip install matplotlib
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#      ---- ---------------------------------- 30.7/294.9 kB 1.3 MB/s eta 0:00:01
#      ----------- ------------------------- 92.2/294.9 kB 871.5 kB/s eta 0:00:01
#      -------------- --------------------- 122.9/294.9 kB 798.9 kB/s eta 0:00:01
#      ---------------------- ------------- 184.3/294.9 kB 926.0 kB/s eta 0:00:01
#      -------------------------------- ----- 256.0/294.9 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 294.9/294.9 kB 1.1 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(corrmat, square=True)
plt.show()

# %%
data3.to_excel(f'{base}/sem01/end_sem.xlsx', index=False)
